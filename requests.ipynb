# %%
import requests
import json

# %%
payload = {'user':'user','password':'password'}
r = requests.get("https://httpbin.org",params = payload)

# %%
print(r)
# Out:
# <Response [200]>

# %%
print(r.url)
# Out:
# https://httpbin.org/?user=user&password=password

# %%
payload = {'key1': 'value1', 'key2': ['value2', 'value3']}

r = requests.get('https://httpbin.org/get', params=payload)
print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2&key2=value3

# %%
r = requests.get('https://api.github.com/events')
r.json()
# Out:
# [{'id': '12266355011',
#   'type': 'CreateEvent',
#   'actor': {'id': 40734257,
#    'login': 'NamYoonJae',
#    'display_login': 'NamYoonJae',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NamYoonJae',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40734257?'},
#   'repo': {'id': 261998267,
#    'name': 'NamYoonJae/exinha',
#    'url': 'https://api.github.com/repos/NamYoonJae/exinha'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': '인하대 게임 개발 c언어(visual studio 2015)',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z'},
#  {'id': '12266355006',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 25033946,
#    'login': 'PRBuilds',
#    'display_login': 'PRBuilds',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PRBuilds',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25033946?'},
#   'repo': {'id': 107111499,
#    'name': 'guardian/dotcom-rendering',
#    'url': 'https://api.github.com/repos/guardian/dotcom-rendering'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/guardian/dotcom-rendering/issues/1464',
#     'repository_url': 'https://api.github.com/repos/guardian/dotcom-rendering',
#     'labels_url': 'https://api.github.com/repos/guardian/dotcom-rendering/issues/1464/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/guardian/dotcom-rendering/issues/1464/comments',
#     'events_url': 'https://api.github.com/repos/guardian/dotcom-rendering/issues/1464/events',
#     'html_url': 'https://github.com/guardian/dotcom-rendering/pull/1464',
#     'id': 613874580,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDE0NTM5ODEy',
#     'number': 1464,
#     'title': 'Rename PullQuoteComponent into PullQuoteBlockComponent',
#     'user': {'login': 'shtukas',
#      'id': 6035518,
#      'node_id': 'MDQ6VXNlcjYwMzU1MTg=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/6035518?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/shtukas',
#      'html_url': 'https://github.com/shtukas',
#      'followers_url': 'https://api.github.com/users/shtukas/followers',
#      'following_url': 'https://api.github.com/users/shtukas/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/shtukas/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/shtukas/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/shtukas/subscriptions',
#      'organizations_url': 'https://api.github.com/users/shtukas/orgs',
#      'repos_url': 'https://api.github.com/users/shtukas/repos',
#      'events_url': 'https://api.github.com/users/shtukas/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/shtukas/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2020-05-07T08:32:54Z',
#     'updated_at': '2020-05-07T08:49:13Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'pull_request': {'url': 'https://api.github.com/repos/guardian/dotcom-rendering/pulls/1464',
#      'html_url': 'https://github.com/guardian/dotcom-rendering/pull/1464',
#      'diff_url': 'https://github.com/guardian/dotcom-rendering/pull/1464.diff',
#      'patch_url': 'https://github.com/guardian/dotcom-rendering/pull/1464.patch'},
#     'body': '## What does this change?\r\n\r\nRename PullQuoteComponent into PullQuoteBlockComponent. See ( https://github.com/guardian/dotcom-rendering/pull/1463 )\r\n'},
#    'comment': {'url': 'https://api.github.com/repos/guardian/dotcom-rendering/issues/comments/625120206',
#     'html_url': 'https://github.com/guardian/dotcom-rendering/pull/1464#issuecomment-625120206',
#     'issue_url': 'https://api.github.com/repos/guardian/dotcom-rendering/issues/1464',
#     'id': 625120206,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDYyNTEyMDIwNg==',
#     'user': {'login': 'PRBuilds',
#      'id': 25033946,
#      'node_id': 'MDQ6VXNlcjI1MDMzOTQ2',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/25033946?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/PRBuilds',
#      'html_url': 'https://github.com/PRBuilds',
#      'followers_url': 'https://api.github.com/users/PRBuilds/followers',
#      'following_url': 'https://api.github.com/users/PRBuilds/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/PRBuilds/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/PRBuilds/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/PRBuilds/subscriptions',
#      'organizations_url': 'https://api.github.com/users/PRBuilds/orgs',
#      'repos_url': 'https://api.github.com/users/PRBuilds/repos',
#      'events_url': 'https://api.github.com/users/PRBuilds/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/PRBuilds/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-05-07T08:49:13Z',
#     'updated_at': '2020-05-07T08:49:13Z',
#     'author_association': 'NONE',
#     'body': '\n\nPRbuilds results:\n\n\n\n\n\n\n\n\n\n\n&#x1F49A; **AMP validation**\n[amp-report.txt](https://s3-eu-west-1.amazonaws.com/prbuilds/PR-1464/amp-report.txt)\n\n\n\n\n\n\n\n**LightHouse Reporting**\n[1588841340.report.html](https://s3-eu-west-1.amazonaws.com/prbuilds/PR-1464/1588841340.report.html)\n\n\n--automated message'}},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z',
#   'org': {'id': 164318,
#    'login': 'guardian',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/guardian',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/164318?'}},
#  {'id': '12266355004',
#   'type': 'CreateEvent',
#   'actor': {'id': 2288294,
#    'login': 'cloudbank',
#    'display_login': 'cloudbank',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cloudbank',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2288294?'},
#   'repo': {'id': 261998268,
#    'name': 'cloudbank/GiveApp',
#    'url': 'https://api.github.com/repos/cloudbank/GiveApp'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z'},
#  {'id': '12266354999',
#   'type': 'PublicEvent',
#   'actor': {'id': 50245116,
#    'login': 'zhoujin1983',
#    'display_login': 'zhoujin1983',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zhoujin1983',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50245116?'},
#   'repo': {'id': 261980170,
#    'name': 'zhoujin1983/Udacity-Data-Analyst-Nanodegree',
#    'url': 'https://api.github.com/repos/zhoujin1983/Udacity-Data-Analyst-Nanodegree'},
#   'payload': {},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z'},
#  {'id': '12266354997',
#   'type': 'CreateEvent',
#   'actor': {'id': 64953932,
#    'login': 'mgmxru',
#    'display_login': 'mgmxru',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mgmxru',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64953932?'},
#   'repo': {'id': 261998266,
#    'name': 'mgmxru/docs',
#    'url': 'https://api.github.com/repos/mgmxru/docs'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z'},
#  {'id': '12266354975',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 31790,
#    'login': 'Ragowit',
#    'display_login': 'Ragowit',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Ragowit',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/31790?'},
#   'repo': {'id': 209039854,
#    'name': 'Ragowit/psn100',
#    'url': 'https://api.github.com/repos/Ragowit/psn100'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/Ragowit/psn100/issues/3601',
#     'repository_url': 'https://api.github.com/repos/Ragowit/psn100',
#     'labels_url': 'https://api.github.com/repos/Ragowit/psn100/issues/3601/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/Ragowit/psn100/issues/3601/comments',
#     'events_url': 'https://api.github.com/repos/Ragowit/psn100/issues/3601/events',
#     'html_url': 'https://github.com/Ragowit/psn100/issues/3601',
#     'id': 597564954,
#     'node_id': 'MDU6SXNzdWU1OTc1NjQ5NTQ=',
#     'number': 3601,
#     'title': 'Lego Marvel Super Heroes',
#     'user': {'login': 'Ragowit',
#      'id': 31790,
#      'node_id': 'MDQ6VXNlcjMxNzkw',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/31790?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Ragowit',
#      'html_url': 'https://github.com/Ragowit',
#      'followers_url': 'https://api.github.com/users/Ragowit/followers',
#      'following_url': 'https://api.github.com/users/Ragowit/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Ragowit/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Ragowit/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Ragowit/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Ragowit/orgs',
#      'repos_url': 'https://api.github.com/users/Ragowit/repos',
#      'events_url': 'https://api.github.com/users/Ragowit/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Ragowit/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1562974670,
#       'node_id': 'MDU6TGFiZWwxNTYyOTc0Njcw',
#       'url': 'https://api.github.com/repos/Ragowit/psn100/labels/merge%20games',
#       'name': 'merge games',
#       'color': 'ed7bb2',
#       'default': False,
#       'description': 'Merge games'}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2020-04-09T21:31:37Z',
#     'updated_at': '2020-05-07T08:49:13Z',
#     'closed_at': '2020-05-07T08:49:13Z',
#     'author_association': 'OWNER',
#     'body': '**Games**\r\n- https://psn100.net/game/2514-lego-marvel-super-heroes-universe-in-peril\r\n- https://psn100.net/game/3786-lego-marvel-super-heroes\r\n- https://psn100.net/game/4219-lego-marvel-super-heroes\r\n\r\nThe PS Vita is its own list. What to do? Ignore the merge?'},
#    'comment': {'url': 'https://api.github.com/repos/Ragowit/psn100/issues/comments/625120204',
#     'html_url': 'https://github.com/Ragowit/psn100/issues/3601#issuecomment-625120204',
#     'issue_url': 'https://api.github.com/repos/Ragowit/psn100/issues/3601',
#     'id': 625120204,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDYyNTEyMDIwNA==',
#     'user': {'login': 'Ragowit',
#      'id': 31790,
#      'node_id': 'MDQ6VXNlcjMxNzkw',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/31790?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Ragowit',
#      'html_url': 'https://github.com/Ragowit',
#      'followers_url': 'https://api.github.com/users/Ragowit/followers',
#      'following_url': 'https://api.github.com/users/Ragowit/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Ragowit/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Ragowit/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Ragowit/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Ragowit/orgs',
#      'repos_url': 'https://api.github.com/users/Ragowit/repos',
#      'events_url': 'https://api.github.com/users/Ragowit/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Ragowit/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-05-07T08:49:13Z',
#     'updated_at': '2020-05-07T08:49:13Z',
#     'author_association': 'OWNER',
#     'body': 'Fixed in 2.11.3\r\n\r\nhttps://psn100.net/game/10515-lego-marvel-super-heroes'}},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z'},
#  {'id': '12266354965',
#   'type': 'CreateEvent',
#   'actor': {'id': 47148648,
#    'login': 'svc-software-factory',
#    'display_login': 'svc-software-factory',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/svc-software-factory',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47148648?'},
#   'repo': {'id': 197735674,
#    'name': 'adeo-gitlab/sync-github-gitlab-21',
#    'url': 'https://api.github.com/repos/adeo-gitlab/sync-github-gitlab-21'},
#   'payload': {'ref': '2020-05-07_08-49-00_682_scenario1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z',
#   'org': {'id': 52697831,
#    'login': 'adeo-gitlab',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/adeo-gitlab',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52697831?'}},
#  {'id': '12266354972',
#   'type': 'WatchEvent',
#   'actor': {'id': 34952977,
#    'login': 'stellaHSR',
#    'display_login': 'stellaHSR',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stellaHSR',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34952977?'},
#   'repo': {'id': 257236246,
#    'name': 'Tencent/TurboTransformers',
#    'url': 'https://api.github.com/repos/Tencent/TurboTransformers'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z',
#   'org': {'id': 18461506,
#    'login': 'Tencent',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Tencent',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18461506?'}},
#  {'id': '12266354974',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 79351,
#    'login': 'mojavelinux',
#    'display_login': 'mojavelinux',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mojavelinux',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/79351?'},
#   'repo': {'id': 15820215,
#    'name': 'asciidoctor/asciidoctor-pdf',
#    'url': 'https://api.github.com/repos/asciidoctor/asciidoctor-pdf'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/asciidoctor/asciidoctor-pdf/issues/1542',
#     'repository_url': 'https://api.github.com/repos/asciidoctor/asciidoctor-pdf',
#     'labels_url': 'https://api.github.com/repos/asciidoctor/asciidoctor-pdf/issues/1542/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/asciidoctor/asciidoctor-pdf/issues/1542/comments',
#     'events_url': 'https://api.github.com/repos/asciidoctor/asciidoctor-pdf/issues/1542/events',
#     'html_url': 'https://github.com/asciidoctor/asciidoctor-pdf/issues/1542',
#     'id': 561535506,
#     'node_id': 'MDU6SXNzdWU1NjE1MzU1MDY=',
#     'number': 1542,
#     'title': 'test suite failures when building RPM',
#     'user': {'login': 'snecklifter',
#      'id': 13884053,
#      'node_id': 'MDQ6VXNlcjEzODg0MDUz',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/13884053?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/snecklifter',
#      'html_url': 'https://github.com/snecklifter',
#      'followers_url': 'https://api.github.com/users/snecklifter/followers',
#      'following_url': 'https://api.github.com/users/snecklifter/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/snecklifter/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/snecklifter/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/snecklifter/subscriptions',
#      'organizations_url': 'https://api.github.com/users/snecklifter/orgs',
#      'repos_url': 'https://api.github.com/users/snecklifter/repos',
#      'events_url': 'https://api.github.com/users/snecklifter/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/snecklifter/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 74447632,
#       'node_id': 'MDU6TGFiZWw3NDQ0NzYzMg==',
#       'url': 'https://api.github.com/repos/asciidoctor/asciidoctor-pdf/labels/bug',
#       'name': 'bug',
#       'color': 'fc2929',
#       'default': True,
#       'description': None}],
#     'state': 'open',
#     'locked': False,
#     'assignee': {'login': 'mojavelinux',
#      'id': 79351,
#      'node_id': 'MDQ6VXNlcjc5MzUx',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/79351?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mojavelinux',
#      'html_url': 'https://github.com/mojavelinux',
#      'followers_url': 'https://api.github.com/users/mojavelinux/followers',
#      'following_url': 'https://api.github.com/users/mojavelinux/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mojavelinux/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mojavelinux/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mojavelinux/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mojavelinux/orgs',
#      'repos_url': 'https://api.github.com/users/mojavelinux/repos',
#      'events_url': 'https://api.github.com/users/mojavelinux/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mojavelinux/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'assignees': [{'login': 'mojavelinux',
#       'id': 79351,
#       'node_id': 'MDQ6VXNlcjc5MzUx',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/79351?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mojavelinux',
#       'html_url': 'https://github.com/mojavelinux',
#       'followers_url': 'https://api.github.com/users/mojavelinux/followers',
#       'following_url': 'https://api.github.com/users/mojavelinux/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mojavelinux/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mojavelinux/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mojavelinux/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mojavelinux/orgs',
#       'repos_url': 'https://api.github.com/users/mojavelinux/repos',
#       'events_url': 'https://api.github.com/users/mojavelinux/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mojavelinux/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'milestone': {'url': 'https://api.github.com/repos/asciidoctor/asciidoctor-pdf/milestones/30',
#      'html_url': 'https://github.com/asciidoctor/asciidoctor-pdf/milestone/30',
#      'labels_url': 'https://api.github.com/repos/asciidoctor/asciidoctor-pdf/milestones/30/labels',
#      'id': 4669472,
#      'node_id': 'MDk6TWlsZXN0b25lNDY2OTQ3Mg==',
#      'number': 30,
#      'title': 'v2.0.0',
#      'description': 'A major release of Asciidoctor PDF marking the switch to Semantic Versioning.',
#      'creator': {'login': 'mojavelinux',
#       'id': 79351,
#       'node_id': 'MDQ6VXNlcjc5MzUx',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/79351?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/mojavelinux',
#       'html_url': 'https://github.com/mojavelinux',
#       'followers_url': 'https://api.github.com/users/mojavelinux/followers',
#       'following_url': 'https://api.github.com/users/mojavelinux/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/mojavelinux/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/mojavelinux/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/mojavelinux/subscriptions',
#       'organizations_url': 'https://api.github.com/users/mojavelinux/orgs',
#       'repos_url': 'https://api.github.com/users/mojavelinux/repos',
#       'events_url': 'https://api.github.com/users/mojavelinux/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/mojavelinux/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 21,
#      'closed_issues': 39,
#      'state': 'open',
#      'created_at': '2019-09-18T07:19:19Z',
#      'updated_at': '2020-05-06T06:32:56Z',
#      'due_on': None,
#      'closed_at': None},
#     'comments': 31,
#     'created_at': '2020-02-07T09:59:37Z',
#     'updated_at': '2020-05-07T08:49:13Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'body': "Hello, sorry for ruby newbie question but I see a few failures when running rspec and comparing results with the expected floats.\r\n\r\nObviously this must be something related to local setup but just wondered any pointers?\r\n\r\n```\r\n  4) Asciidoctor::PDF::Converter - Cover Page should not allow page size of PDF cover page to affect page size of document\r\n     Failure/Error: (expect pdf.pages[0][:size]).to eql PDF::Core::PageGeometry::SIZES['LETTER']\r\n       expected: [612.0, 792.0]\r\n            got: [612, 792]\r\n       (compared using eql?)\r\n     # ./spec/cover_page_spec.rb:181:in `block (2 levels) in <top (required)>'\r\n  5) Asciidoctor::PDF::Converter - Font font sizes should resolve font size of inline element specified in rem\r\n     Failure/Error: (expect linked_text[:font_size]).to eql 9.0\r\n       expected: 9.0\r\n            got: 9\r\n       (compared using eql?)\r\n     # ./spec/font_spec.rb:224:in `block (3 levels) in <top (required)>'\r\n  6) Asciidoctor::PDF::Converter - Image SVG should replace unrecognized font family with base font family\r\n     Failure/Error: (expect text[0][:font_size]).to eql 12.0\r\n       expected: 12.0\r\n            got: 12\r\n       (compared using eql?)\r\n     # ./spec/image_spec.rb:187:in `block (3 levels) in <top (required)>'\r\n  7) Asciidoctor::PDF::Converter - Image SVG should replace unrecognized font family in SVG with SVG fallback font family if specified in theme\r\n     Failure/Error: (expect text[0][:font_size]).to eql 12.0\r\n       expected: 12.0\r\n            got: 12\r\n       (compared using eql?)\r\n```"},
#    'comment': {'url': 'https://api.github.com/repos/asciidoctor/asciidoctor-pdf/issues/comments/625120205',
#     'html_url': 'https://github.com/asciidoctor/asciidoctor-pdf/issues/1542#issuecomment-625120205',
#     'issue_url': 'https://api.github.com/repos/asciidoctor/asciidoctor-pdf/issues/1542',
#     'id': 625120205,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDYyNTEyMDIwNQ==',
#     'user': {'login': 'mojavelinux',
#      'id': 79351,
#      'node_id': 'MDQ6VXNlcjc5MzUx',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/79351?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mojavelinux',
#      'html_url': 'https://github.com/mojavelinux',
#      'followers_url': 'https://api.github.com/users/mojavelinux/followers',
#      'following_url': 'https://api.github.com/users/mojavelinux/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mojavelinux/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mojavelinux/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mojavelinux/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mojavelinux/orgs',
#      'repos_url': 'https://api.github.com/users/mojavelinux/repos',
#      'events_url': 'https://api.github.com/users/mojavelinux/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mojavelinux/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-05-07T08:49:13Z',
#     'updated_at': '2020-05-07T08:49:13Z',
#     'author_association': 'MEMBER',
#     'body': "Thanks again for the insight.\r\n\r\n> There is no reason why the test suite could not be executed as PATH=some/path/to/bindir:$PATH rspec spec\r\n\r\nDoing that would violate the assertion the test is trying to make, which is that the bin script belongs to the gem (not something that's global to the path).\r\n\r\n>  I don't think it would be smart to use them in upstream code\r\n\r\nI think it would be very smart because what we're trying to do here is introduce an exception for running the test suite in a non-standard Ruby environment. I need to know that's what's going on so that I can introduce the exception.\r\n\r\nI'll play around and see what I can come up with."}},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z',
#   'org': {'id': 3137042,
#    'login': 'asciidoctor',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/asciidoctor',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3137042?'}},
#  {'id': '12266354969',
#   'type': 'CreateEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 194111389,
#    'name': 'KennethWussmann/discord-temperature',
#    'url': 'https://api.github.com/repos/KennethWussmann/discord-temperature'},
#   'payload': {'ref': 'dependabot/maven/net.dv8tion-JDA-4.1.1_145',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Spring Boot Kotlin application that shows the current temperature in rooms as Discord status',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z'},
#  {'id': '12266354966',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 56340355,
#    'login': 'galawin59',
#    'display_login': 'galawin59',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/galawin59',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56340355?'},
#   'repo': {'id': 233546720,
#    'name': 'Alkadir/GolemProject',
#    'url': 'https://api.github.com/repos/Alkadir/GolemProject'},
#   'payload': {'action': 'closed',
#    'number': 383,
#    'pull_request': {'url': 'https://api.github.com/repos/Alkadir/GolemProject/pulls/383',
#     'id': 414547727,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDE0NTQ3NzI3',
#     'html_url': 'https://github.com/Alkadir/GolemProject/pull/383',
#     'diff_url': 'https://github.com/Alkadir/GolemProject/pull/383.diff',
#     'patch_url': 'https://github.com/Alkadir/GolemProject/pull/383.patch',
#     'issue_url': 'https://api.github.com/repos/Alkadir/GolemProject/issues/383',
#     'number': 383,
#     'state': 'closed',
#     'locked': False,
#     'title': 'modif lvl(interupt lvl 8) ',
#     'user': {'login': 'galawin59',
#      'id': 56340355,
#      'node_id': 'MDQ6VXNlcjU2MzQwMzU1',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/56340355?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/galawin59',
#      'html_url': 'https://github.com/galawin59',
#      'followers_url': 'https://api.github.com/users/galawin59/followers',
#      'following_url': 'https://api.github.com/users/galawin59/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/galawin59/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/galawin59/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/galawin59/subscriptions',
#      'organizations_url': 'https://api.github.com/users/galawin59/orgs',
#      'repos_url': 'https://api.github.com/users/galawin59/repos',
#      'events_url': 'https://api.github.com/users/galawin59/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/galawin59/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2020-05-07T08:49:06Z',
#     'updated_at': '2020-05-07T08:49:13Z',
#     'closed_at': '2020-05-07T08:49:13Z',
#     'merged_at': '2020-05-07T08:49:12Z',
#     'merge_commit_sha': '94ea26b8ed4fc533003fae7a78bbd0b36eae474a',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/Alkadir/GolemProject/pulls/383/commits',
#     'review_comments_url': 'https://api.github.com/repos/Alkadir/GolemProject/pulls/383/comments',
#     'review_comment_url': 'https://api.github.com/repos/Alkadir/GolemProject/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Alkadir/GolemProject/issues/383/comments',
#     'statuses_url': 'https://api.github.com/repos/Alkadir/GolemProject/statuses/0f214715ea6db0cdbeadb8479f3e79615400a039',
#     'head': {'label': 'Alkadir:Patrick',
#      'ref': 'Patrick',
#      'sha': '0f214715ea6db0cdbeadb8479f3e79615400a039',
#      'user': {'login': 'Alkadir',
#       'id': 56340594,
#       'node_id': 'MDQ6VXNlcjU2MzQwNTk0',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/56340594?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Alkadir',
#       'html_url': 'https://github.com/Alkadir',
#       'followers_url': 'https://api.github.com/users/Alkadir/followers',
#       'following_url': 'https://api.github.com/users/Alkadir/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Alkadir/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Alkadir/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Alkadir/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Alkadir/orgs',
#       'repos_url': 'https://api.github.com/users/Alkadir/repos',
#       'events_url': 'https://api.github.com/users/Alkadir/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Alkadir/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 233546720,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMzM1NDY3MjA=',
#       'name': 'GolemProject',
#       'full_name': 'Alkadir/GolemProject',
#       'private': False,
#       'owner': {'login': 'Alkadir',
#        'id': 56340594,
#        'node_id': 'MDQ6VXNlcjU2MzQwNTk0',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/56340594?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Alkadir',
#        'html_url': 'https://github.com/Alkadir',
#        'followers_url': 'https://api.github.com/users/Alkadir/followers',
#        'following_url': 'https://api.github.com/users/Alkadir/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Alkadir/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Alkadir/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Alkadir/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Alkadir/orgs',
#        'repos_url': 'https://api.github.com/users/Alkadir/repos',
#        'events_url': 'https://api.github.com/users/Alkadir/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Alkadir/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Alkadir/GolemProject',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/Alkadir/GolemProject',
#       'forks_url': 'https://api.github.com/repos/Alkadir/GolemProject/forks',
#       'keys_url': 'https://api.github.com/repos/Alkadir/GolemProject/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Alkadir/GolemProject/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Alkadir/GolemProject/teams',
#       'hooks_url': 'https://api.github.com/repos/Alkadir/GolemProject/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Alkadir/GolemProject/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Alkadir/GolemProject/events',
#       'assignees_url': 'https://api.github.com/repos/Alkadir/GolemProject/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Alkadir/GolemProject/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Alkadir/GolemProject/tags',
#       'blobs_url': 'https://api.github.com/repos/Alkadir/GolemProject/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Alkadir/GolemProject/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Alkadir/GolemProject/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Alkadir/GolemProject/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Alkadir/GolemProject/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Alkadir/GolemProject/languages',
#       'stargazers_url': 'https://api.github.com/repos/Alkadir/GolemProject/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Alkadir/GolemProject/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Alkadir/GolemProject/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Alkadir/GolemProject/subscription',
#       'commits_url': 'https://api.github.com/repos/Alkadir/GolemProject/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Alkadir/GolemProject/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Alkadir/GolemProject/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Alkadir/GolemProject/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Alkadir/GolemProject/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Alkadir/GolemProject/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Alkadir/GolemProject/merges',
#       'archive_url': 'https://api.github.com/repos/Alkadir/GolemProject/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Alkadir/GolemProject/downloads',
#       'issues_url': 'https://api.github.com/repos/Alkadir/GolemProject/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Alkadir/GolemProject/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Alkadir/GolemProject/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Alkadir/GolemProject/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Alkadir/GolemProject/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Alkadir/GolemProject/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Alkadir/GolemProject/deployments',
#       'created_at': '2020-01-13T08:27:32Z',
#       'updated_at': '2020-05-07T08:45:34Z',
#       'pushed_at': '2020-05-07T08:49:12Z',
#       'git_url': 'git://github.com/Alkadir/GolemProject.git',
#       'ssh_url': 'git@github.com:Alkadir/GolemProject.git',
#       'clone_url': 'https://github.com/Alkadir/GolemProject.git',
#       'svn_url': 'https://github.com/Alkadir/GolemProject',
#       'homepage': None,
#       'size': 2354808,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'C++',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'Alkadir:master',
#      'ref': 'master',
#      'sha': 'fe7b783813d80d9f0f9672e5df3b26ab090a2b3c',
#      'user': {'login': 'Alkadir',
#       'id': 56340594,
#       'node_id': 'MDQ6VXNlcjU2MzQwNTk0',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/56340594?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Alkadir',
#       'html_url': 'https://github.com/Alkadir',
#       'followers_url': 'https://api.github.com/users/Alkadir/followers',
#       'following_url': 'https://api.github.com/users/Alkadir/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Alkadir/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Alkadir/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Alkadir/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Alkadir/orgs',
#       'repos_url': 'https://api.github.com/users/Alkadir/repos',
#       'events_url': 'https://api.github.com/users/Alkadir/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Alkadir/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 233546720,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMzM1NDY3MjA=',
#       'name': 'GolemProject',
#       'full_name': 'Alkadir/GolemProject',
#       'private': False,
#       'owner': {'login': 'Alkadir',
#        'id': 56340594,
#        'node_id': 'MDQ6VXNlcjU2MzQwNTk0',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/56340594?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Alkadir',
#        'html_url': 'https://github.com/Alkadir',
#        'followers_url': 'https://api.github.com/users/Alkadir/followers',
#        'following_url': 'https://api.github.com/users/Alkadir/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Alkadir/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Alkadir/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Alkadir/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Alkadir/orgs',
#        'repos_url': 'https://api.github.com/users/Alkadir/repos',
#        'events_url': 'https://api.github.com/users/Alkadir/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Alkadir/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Alkadir/GolemProject',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/Alkadir/GolemProject',
#       'forks_url': 'https://api.github.com/repos/Alkadir/GolemProject/forks',
#       'keys_url': 'https://api.github.com/repos/Alkadir/GolemProject/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/Alkadir/GolemProject/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/Alkadir/GolemProject/teams',
#       'hooks_url': 'https://api.github.com/repos/Alkadir/GolemProject/hooks',
#       'issue_events_url': 'https://api.github.com/repos/Alkadir/GolemProject/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/Alkadir/GolemProject/events',
#       'assignees_url': 'https://api.github.com/repos/Alkadir/GolemProject/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/Alkadir/GolemProject/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/Alkadir/GolemProject/tags',
#       'blobs_url': 'https://api.github.com/repos/Alkadir/GolemProject/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/Alkadir/GolemProject/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/Alkadir/GolemProject/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/Alkadir/GolemProject/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/Alkadir/GolemProject/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/Alkadir/GolemProject/languages',
#       'stargazers_url': 'https://api.github.com/repos/Alkadir/GolemProject/stargazers',
#       'contributors_url': 'https://api.github.com/repos/Alkadir/GolemProject/contributors',
#       'subscribers_url': 'https://api.github.com/repos/Alkadir/GolemProject/subscribers',
#       'subscription_url': 'https://api.github.com/repos/Alkadir/GolemProject/subscription',
#       'commits_url': 'https://api.github.com/repos/Alkadir/GolemProject/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/Alkadir/GolemProject/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/Alkadir/GolemProject/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/Alkadir/GolemProject/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/Alkadir/GolemProject/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/Alkadir/GolemProject/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/Alkadir/GolemProject/merges',
#       'archive_url': 'https://api.github.com/repos/Alkadir/GolemProject/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/Alkadir/GolemProject/downloads',
#       'issues_url': 'https://api.github.com/repos/Alkadir/GolemProject/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/Alkadir/GolemProject/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/Alkadir/GolemProject/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/Alkadir/GolemProject/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Alkadir/GolemProject/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Alkadir/GolemProject/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Alkadir/GolemProject/deployments',
#       'created_at': '2020-01-13T08:27:32Z',
#       'updated_at': '2020-05-07T08:45:34Z',
#       'pushed_at': '2020-05-07T08:49:12Z',
#       'git_url': 'git://github.com/Alkadir/GolemProject.git',
#       'ssh_url': 'git@github.com:Alkadir/GolemProject.git',
#       'clone_url': 'https://github.com/Alkadir/GolemProject.git',
#       'svn_url': 'https://github.com/Alkadir/GolemProject',
#       'homepage': None,
#       'size': 2354808,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'C++',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Alkadir/GolemProject/pulls/383'},
#      'html': {'href': 'https://github.com/Alkadir/GolemProject/pull/383'},
#      'issue': {'href': 'https://api.github.com/repos/Alkadir/GolemProject/issues/383'},
#      'comments': {'href': 'https://api.github.com/repos/Alkadir/GolemProject/issues/383/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Alkadir/GolemProject/pulls/383/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Alkadir/GolemProject/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Alkadir/GolemProject/pulls/383/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Alkadir/GolemProject/statuses/0f214715ea6db0cdbeadb8479f3e79615400a039'}},
#     'author_association': 'COLLABORATOR',
#     'merged': True,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': {'login': 'galawin59',
#      'id': 56340355,
#      'node_id': 'MDQ6VXNlcjU2MzQwMzU1',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/56340355?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/galawin59',
#      'html_url': 'https://github.com/galawin59',
#      'followers_url': 'https://api.github.com/users/galawin59/followers',
#      'following_url': 'https://api.github.com/users/galawin59/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/galawin59/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/galawin59/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/galawin59/subscriptions',
#      'organizations_url': 'https://api.github.com/users/galawin59/orgs',
#      'repos_url': 'https://api.github.com/users/galawin59/repos',
#      'events_url': 'https://api.github.com/users/galawin59/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/galawin59/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 2,
#     'additions': 0,
#     'deletions': 0,
#     'changed_files': 2}},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z'},
#  {'id': '12266354964',
#   'type': 'PushEvent',
#   'actor': {'id': 61230475,
#    'login': 'kana-chan',
#    'display_login': 'kana-chan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kana-chan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61230475?'},
#   'repo': {'id': 246769397,
#    'name': 'kana-chan/port-folio',
#    'url': 'https://api.github.com/repos/kana-chan/port-folio'},
#   'payload': {'push_id': 5034397318,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/update/contents_show_page_4',
#    'head': 'fab013f5a8f1c6b9b7d148542c44b12643916d32',
#    'before': '66821218e3795e28f7eab4e4cb07a98a44210b45',
#    'commits': [{'sha': 'fab013f5a8f1c6b9b7d148542c44b12643916d32',
#      'author': {'email': 'bkm0115_y@icloud.com', 'name': 'kana-chan'},
#      'message': 'change scroll file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kana-chan/port-folio/commits/fab013f5a8f1c6b9b7d148542c44b12643916d32'}]},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z'},
#  {'id': '12266354962',
#   'type': 'PushEvent',
#   'actor': {'id': 60598291,
#    'login': 'S-Thibault',
#    'display_login': 'S-Thibault',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/S-Thibault',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60598291?'},
#   'repo': {'id': 261405006,
#    'name': 'S-Thibault/integration-template-restaurant',
#    'url': 'https://api.github.com/repos/S-Thibault/integration-template-restaurant'},
#   'payload': {'push_id': 5034397324,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '3e76a3f7de043bdc7f80d1b8e4adc8d38020895e',
#    'before': 'c5af034dcf62d52042fa4383955d9189c69fa876',
#    'commits': [{'sha': '3e76a3f7de043bdc7f80d1b8e4adc8d38020895e',
#      'author': {'email': 'sylvain.thibault@infamail.com',
#       'name': 'S-Thibault'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/S-Thibault/integration-template-restaurant/commits/3e76a3f7de043bdc7f80d1b8e4adc8d38020895e'}]},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z'},
#  {'id': '12266354947',
#   'type': 'PushEvent',
#   'actor': {'id': 18616660,
#    'login': 'janmager',
#    'display_login': 'janmager',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/janmager',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18616660?'},
#   'repo': {'id': 260591159,
#    'name': 'janmager/modern-kitchen-book',
#    'url': 'https://api.github.com/repos/janmager/modern-kitchen-book'},
#   'payload': {'push_id': 5034397304,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '5f0b605e707c2d80a9a607fc51f23f846bd622f6',
#    'before': '2a81f227c5090cf1d7edb34dfb3308fb20144c42',
#    'commits': [{'sha': '5f0b605e707c2d80a9a607fc51f23f846bd622f6',
#      'author': {'email': 'jasiu.mager@gmail.com', 'name': 'janmager'},
#      'message': 'back to home button',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/janmager/modern-kitchen-book/commits/5f0b605e707c2d80a9a607fc51f23f846bd622f6'}]},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z'},
#  {'id': '12266354943',
#   'type': 'PushEvent',
#   'actor': {'id': 51675567,
#    'login': 'ivgasa99',
#    'display_login': 'ivgasa99',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ivgasa99',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51675567?'},
#   'repo': {'id': 245626314,
#    'name': 'Pau6b/tmUp',
#    'url': 'https://api.github.com/repos/Pau6b/tmUp'},
#   'payload': {'push_id': 5034397313,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/SecondMaster',
#    'head': 'd8cb4ba55f39933eeb46ed52e774d49e542a6467',
#    'before': '02d581ca5454647b996942cfa5f5b733f5320698',
#    'commits': [{'sha': '4603420d86bdcda91501e245c376b15475d64843',
#      'author': {'email': 'ivan.garcia.sanchez@est.fib.upc.edu',
#       'name': 'Ivan'},
#      'message': 'convocatorias',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/Pau6b/tmUp/commits/4603420d86bdcda91501e245c376b15475d64843'},
#     {'sha': 'd8cb4ba55f39933eeb46ed52e774d49e542a6467',
# ...
#       'notifications_url': 'https://api.github.com/repos/Waiviogit/waivio/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/Waiviogit/waivio/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/Waiviogit/waivio/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/Waiviogit/waivio/deployments',
#       'created_at': '2018-10-29T10:42:26Z',
#       'updated_at': '2020-05-01T16:52:36Z',
#       'pushed_at': '2020-05-07T08:48:53Z',
#       'git_url': 'git://github.com/Waiviogit/waivio.git',
#       'ssh_url': 'git@github.com:Waiviogit/waivio.git',
#       'clone_url': 'https://github.com/Waiviogit/waivio.git',
#       'svn_url': 'https://github.com/Waiviogit/waivio',
#       'homepage': None,
#       'size': 15801,
#       'stargazers_count': 4,
#       'watchers_count': 4,
#       'language': 'JavaScript',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': True,
#       'forks_count': 4,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 223,
#       'license': {'key': 'mit',
#        'name': 'MIT License',
#        'spdx_id': 'MIT',
#        'url': 'https://api.github.com/licenses/mit',
#        'node_id': 'MDc6TGljZW5zZTEz'},
#       'forks': 4,
#       'open_issues': 223,
#       'watchers': 4,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/Waiviogit/waivio/pulls/872'},
#      'html': {'href': 'https://github.com/Waiviogit/waivio/pull/872'},
#      'issue': {'href': 'https://api.github.com/repos/Waiviogit/waivio/issues/872'},
#      'comments': {'href': 'https://api.github.com/repos/Waiviogit/waivio/issues/872/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/Waiviogit/waivio/pulls/872/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/Waiviogit/waivio/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/Waiviogit/waivio/pulls/872/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/Waiviogit/waivio/statuses/3a230879e0cdbf8d930297831ae8a2df829b4727'}},
#     'author_association': 'COLLABORATOR',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 3,
#     'additions': 7,
#     'deletions': 11,
#     'changed_files': 3}},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z'},
#  {'id': '12266354941',
#   'type': 'PushEvent',
#   'actor': {'id': 22865877,
#    'login': 'EnesGokceDS',
#    'display_login': 'EnesGokceDS',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/EnesGokceDS',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22865877?'},
#   'repo': {'id': 250328748,
#    'name': 'EnesGokceDS/Amazon_Reviews_NLP_Capstone_Project',
#    'url': 'https://api.github.com/repos/EnesGokceDS/Amazon_Reviews_NLP_Capstone_Project'},
#   'payload': {'push_id': 5034397297,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '44271d1b290f322c42724b6740a949dd598dfb62',
#    'before': '5cef084ce67369dd151107dcdcb19adf08e8383d',
#    'commits': [{'sha': '44271d1b290f322c42724b6740a949dd598dfb62',
#      'author': {'email': 'enesgokce@gmail.com', 'name': 'Enes Gokce'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/EnesGokceDS/Amazon_Reviews_NLP_Capstone_Project/commits/44271d1b290f322c42724b6740a949dd598dfb62'}]},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z'},
#  {'id': '12266354931',
#   'type': 'PushEvent',
#   'actor': {'id': 32889038,
#    'login': 'chenjianfei2017',
#    'display_login': 'chenjianfei2017',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chenjianfei2017',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/32889038?'},
#   'repo': {'id': 39093389,
#    'name': 'Azure/azure-rest-api-specs',
#    'url': 'https://api.github.com/repos/Azure/azure-rest-api-specs'},
#   'payload': {'push_id': 5034397286,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/pipeline-devops',
#    'head': '2e035a053b57a17e4157ff56f53fa0036184de1a',
#    'before': 'bdd5a6ecbab7344b6d0184f05ff34333be3761f0',
#    'commits': [{'sha': '2e035a053b57a17e4157ff56f53fa0036184de1a',
#      'author': {'email': '32889038+chenjianfei2017@users.noreply.github.com',
#       'name': '陈箭飞'},
#      'message': 'Update readme.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Azure/azure-rest-api-specs/commits/2e035a053b57a17e4157ff56f53fa0036184de1a'}]},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z',
#   'org': {'id': 6844498,
#    'login': 'Azure',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Azure',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6844498?'}},
#  {'id': '12266354922',
#   'type': 'PushEvent',
#   'actor': {'id': 4030466,
#    'login': 'assapir',
#    'display_login': 'assapir',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/assapir',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4030466?'},
#   'repo': {'id': 190439329,
#    'name': 'assapir/story-line',
#    'url': 'https://api.github.com/repos/assapir/story-line'},
#   'payload': {'push_id': 5034397293,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/github-ui',
#    'head': 'e5c2e4193ffaf62cf4e451312f19b9bb5ad58a08',
#    'before': '01fde5ba6f991b68dcbb13cd5c5efaf6b53a9e4d',
#    'commits': [{'sha': 'e5c2e4193ffaf62cf4e451312f19b9bb5ad58a08',
#      'author': {'email': 'assapir@microsoft.com', 'name': 'Assaf Sapir'},
#      'message': 'not working yet for some reason',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/assapir/story-line/commits/e5c2e4193ffaf62cf4e451312f19b9bb5ad58a08'}]},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z'},
#  {'id': '12266354924',
#   'type': 'CreateEvent',
#   'actor': {'id': 47175500,
#    'login': 'hello-HelloWorld',
#    'display_login': 'hello-HelloWorld',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hello-HelloWorld',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47175500?'},
#   'repo': {'id': 261998265,
#    'name': 'hello-HelloWorld/tf',
#    'url': 'https://api.github.com/repos/hello-HelloWorld/tf'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': '大数据项目案例-堵车预测',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z'},
#  {'id': '12266354918',
#   'type': 'PushEvent',
#   'actor': {'id': 3355051,
#    'login': 'arnaud4d',
#    'display_login': 'arnaud4d',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/arnaud4d',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3355051?'},
#   'repo': {'id': 175236375,
#    'name': '4d/docs',
#    'url': 'https://api.github.com/repos/4d/docs'},
#   'payload': {'push_id': 5034397287,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/l10n_master',
#    'head': '3878e776c94043563b4419b9a6351a3472b0d124',
#    'before': 'fb7f8276e5654ef4ab0d0b7309b0af41c783fb32',
#    'commits': [{'sha': '3878e776c94043563b4419b9a6351a3472b0d124',
#      'author': {'email': 'savagetomatoes@gmail.com', 'name': 'arnaud4d'},
#      'message': 'New translations dt_boolean.md (French)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/4d/docs/commits/3878e776c94043563b4419b9a6351a3472b0d124'}]},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z',
#   'org': {'id': 84562,
#    'login': '4d',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/4d',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/84562?'}},
#  {'id': '12266354912',
#   'type': 'PushEvent',
#   'actor': {'id': 61190403,
#    'login': 'kohayan',
#    'display_login': 'kohayan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kohayan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61190403?'},
#   'repo': {'id': 260165466,
#    'name': 'kohayan/Q.flat',
#    'url': 'https://api.github.com/repos/kohayan/Q.flat'},
#   'payload': {'push_id': 5034397281,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/develop',
#    'head': '96668f6bc6be431a4116c53992507343af218a7f',
#    'before': 'bd19dcbb8cedde977cf6a54f42ad2f51616e3b3e',
#    'commits': [{'sha': '1beaa349c7aaadb15a01ed3b3b9bf47c90490b4c',
#      'author': {'email': 'disney.2381509@gmail.com', 'name': 'kohayan'},
#      'message': 'fix routes',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/kohayan/Q.flat/commits/1beaa349c7aaadb15a01ed3b3b9bf47c90490b4c'},
#     {'sha': '96668f6bc6be431a4116c53992507343af218a7f',
#      'author': {'email': '61190403+kohayan@users.noreply.github.com',
#       'name': 'kohayan'},
#      'message': 'Merge pull request #4 from kohayan/fix-routes\n\nfix routes',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kohayan/Q.flat/commits/96668f6bc6be431a4116c53992507343af218a7f'}]},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z'},
#  {'id': '12266354903',
#   'type': 'PushEvent',
#   'actor': {'id': 6808146,
#    'login': 'cristiangheorghe10',
#    'display_login': 'cristiangheorghe10',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cristiangheorghe10',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6808146?'},
#   'repo': {'id': 171704165,
#    'name': 'sorinpopescu/BlueBerry',
#    'url': 'https://api.github.com/repos/sorinpopescu/BlueBerry'},
#   'payload': {'push_id': 5034397277,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7bd166139cff2d178631bde6a56ffe91dbf500f5',
#    'before': 'cb4dbd971933a3989268af32cd201a727ea8be73',
#    'commits': [{'sha': '7bd166139cff2d178631bde6a56ffe91dbf500f5',
#      'author': {'email': 'cristtian.gheorghe@gmail.com',
#       'name': 'delpiero10_C'},
#      'message': 'update breadcrumb 2:07.07.2020',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sorinpopescu/BlueBerry/commits/7bd166139cff2d178631bde6a56ffe91dbf500f5'}]},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z'},
#  {'id': '12266354896',
#   'type': 'PushEvent',
#   'actor': {'id': 59292315,
#    'login': 'quentinCharrier',
#    'display_login': 'quentinCharrier',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/quentinCharrier',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59292315?'},
#   'repo': {'id': 250318638,
#    'name': 'quentinCharrier/cookie-consent-bundle',
#    'url': 'https://api.github.com/repos/quentinCharrier/cookie-consent-bundle'},
#   'payload': {'push_id': 5034397270,
#    'size': 5,
#    'distinct_size': 4,
#    'ref': 'refs/heads/master',
#    'head': '043112290702953af8f038573c92f8af24b2e29a',
#    'before': 'b42459f406f2faeea1d3401e27dab2c2f4459514',
#    'commits': [{'sha': '68a2208f212ff6d2cea81bdd44fd02678851ef23',
#      'author': {'email': 'quent1993@gmail.com', 'name': 'quentinCharrier'},
#      'message': 'Adjust Readme with sylius and themes assets',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/quentinCharrier/cookie-consent-bundle/commits/68a2208f212ff6d2cea81bdd44fd02678851ef23'},
#     {'sha': '5fd8cb2f6cd8ad88b9d4c7b6d079aca5dbb7e5c8',
#      'author': {'email': 'quent1993@gmail.com', 'name': 'quentinCharrier'},
#      'message': 'Adjust Readme with sylius and themes assets',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/quentinCharrier/cookie-consent-bundle/commits/5fd8cb2f6cd8ad88b9d4c7b6d079aca5dbb7e5c8'},
#     {'sha': 'e9834291fab5b3bbb1f9a8aad2cc323e3c8fbccd',
#      'author': {'email': 'quent1993@gmail.com', 'name': 'quentinCharrier'},
#      'message': 'Add configurable path to cookie policy',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/quentinCharrier/cookie-consent-bundle/commits/e9834291fab5b3bbb1f9a8aad2cc323e3c8fbccd'},
#     {'sha': 'b563947850aac0b044561a109c75de2440d618ad',
#      'author': {'email': 'quent1993@gmail.com', 'name': 'quentinCharrier'},
#      'message': 'Add configurable path to cookie policy',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/quentinCharrier/cookie-consent-bundle/commits/b563947850aac0b044561a109c75de2440d618ad'},
#     {'sha': '043112290702953af8f038573c92f8af24b2e29a',
#      'author': {'email': 'quent1993@gmail.com', 'name': 'quentinCharrier'},
#      'message': "Merge branch 'dev'",
#      'distinct': True,
#      'url': 'https://api.github.com/repos/quentinCharrier/cookie-consent-bundle/commits/043112290702953af8f038573c92f8af24b2e29a'}]},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z'},
#  {'id': '12266354899',
#   'type': 'PushEvent',
#   'actor': {'id': 51158509,
#    'login': 'izomerilija',
#    'display_login': 'izomerilija',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/izomerilija',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/51158509?'},
#   'repo': {'id': 250790740,
#    'name': 'izomerilija/Olimpijada-model',
#    'url': 'https://api.github.com/repos/izomerilija/Olimpijada-model'},
#   'payload': {'push_id': 5034397276,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '8ca15ca1970e0503b55b9a025837964152ea8cbf',
#    'before': 'df2bc3ba6778441337b66046699ad8debb080824',
#    'commits': [{'sha': '8ca15ca1970e0503b55b9a025837964152ea8cbf',
#      'author': {'email': 'ekrstonosic@gmail.com',
#       'name': 'Emilija Krstonošić'},
#      'message': 'C++17, tested\n\nuspešno generiše atletičare random imena, prezimena i rezultata',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/izomerilija/Olimpijada-model/commits/8ca15ca1970e0503b55b9a025837964152ea8cbf'}]},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z'},
#  {'id': '12266354892',
#   'type': 'PushEvent',
#   'actor': {'id': 10594945,
#    'login': 'romainbsl',
#    'display_login': 'romainbsl',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/romainbsl',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10594945?'},
#   'repo': {'id': 236804204,
#    'name': 'Kodein-Framework/Kodein-Type',
#    'url': 'https://api.github.com/repos/Kodein-Framework/Kodein-Type'},
#   'payload': {'push_id': 5034397264,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/feature/build',
#    'head': 'ab2701649ec284bcddbb982bc1ce3076e20419af',
#    'before': '922729ea7d7223a7c765bfec2fae00dfb5fc99bc',
#    'commits': [{'sha': 'ab2701649ec284bcddbb982bc1ce3076e20419af',
#      'author': {'email': 'romain@boisselle.dev', 'name': 'Romain Boisselle'},
#      'message': '    build test windows',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Kodein-Framework/Kodein-Type/commits/ab2701649ec284bcddbb982bc1ce3076e20419af'}]},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z',
#   'org': {'id': 37698276,
#    'login': 'Kodein-Framework',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Kodein-Framework',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37698276?'}},
#  {'id': '12266354882',
#   'type': 'PushEvent',
#   'actor': {'id': 325316,
#    'login': 'aspcodenet',
#    'display_login': 'aspcodenet',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aspcodenet',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/325316?'},
#   'repo': {'id': 250241533,
#    'name': 'aspcodenet/MVC2HarrysSMS',
#    'url': 'https://api.github.com/repos/aspcodenet/MVC2HarrysSMS'},
#   'payload': {'push_id': 5034397263,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '997efef9bc6ac584ca04876f4274ca10eaaf7491',
#    'before': '76ae7b0f422a487ff7bb64adae085af8a839fc58',
#    'commits': [{'sha': '997efef9bc6ac584ca04876f4274ca10eaaf7491',
#      'author': {'email': 'stefan.holmberg@systementor.se',
#       'name': 'Stefan Holmberg'},
#      'message': 'ControllerTests',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/aspcodenet/MVC2HarrysSMS/commits/997efef9bc6ac584ca04876f4274ca10eaaf7491'}]},
#   'public': True,
#   'created_at': '2020-05-07T08:49:13Z'}]

# %%
payload = {'key1': 'value1', 'key2': 'value2'}

r = requests.post("https://httpbin.org/post", data=payload)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.22.0",
#     "X-Amzn-Trace-Id": "Root=1-5eb3cd04-e0d3047d51e7a9ca2e7efeef"
#   },
#   "json": null,
#   "origin": "47.8.101.122",
#   "url": "https://httpbin.org/post"
# }

# %%
payload_tuples = [('key1', 'value1'), ('key1', 'value2')]
r1 = requests.post('https://httpbin.org/post', data=payload_tuples)
payload_dict = {'key1': ['value1', 'value2']}
r2 = requests.post('https://httpbin.org/post', data=payload_dict)
print(r1.text)
print()
print(r2.text)
print()
print(r1.text == r2.text)
print(r1.json() == r2.json())
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": [
#       "value1",
#       "value2"
#     ]
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.22.0",
#     "X-Amzn-Trace-Id": "Root=1-5eb3d103-131cc060b774d83a734f7d9c"
#   },
#   "json": null,
#   "origin": "47.8.43.60",
#   "url": "https://httpbin.org/post"
# }
#
#
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "key1": [
#       "value1",
#       "value2"
#     ]
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Content-Length": "23",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.22.0",
#     "X-Amzn-Trace-Id": "Root=1-5eb3d105-0de33000c7a151c0702dbc28"
#   },
#   "json": null,
#   "origin": "47.8.43.60",
#   "url": "https://httpbin.org/post"
# }
#
#
# False
# False

# %%
url = 'https://api.github.com/some/endpoint'
payload = {'some': 'data'}
r = requests.post(url, data=json.dumps(payload))

# %%
print(r.content)
# Out:
# b'{"message":"Not Found","documentation_url":"https://developer.github.com/v3"}'

# %%
url = 'https://api.github.com/some/endpoint'
payload = {'some': 'data'}
r = requests.post(url, json = payload)

# %%
print(r.content)
# Out:
# b'{"message":"Not Found","documentation_url":"https://developer.github.com/v3"}'
